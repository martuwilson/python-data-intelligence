# %% [markdown]
# # Analisis de Sentimientos
# ## Usando el modelo entrenado por Naive Bayes
#
# Implementación de un análisis de sentimientos con un modelo pre entrenado para el proceso del texto.

# %%
from classifier import SentimentClassifier

clf = SentimentClassifier()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from classifier import SentimentClassifier
#       3 clf = SentimentClassifier()
#
# ModuleNotFoundError: No module named 'classifier'
