# %%
## Importacion
import matplotlib.pyplot as plt
## con agregar aca la linea: %matplotlib inline no hace falta el show pero luego del plot va un ;

# %%
numeros = [4,2,7,6,3]

plt.plot(numeros) # Mostrar los datos en el grafico
plt.savefig('primer_graf.png') # puede ponerse la ruta entera para saber donde guardarlo
#plt.show() # Mostrar el gráfico

# %%
# show hace mucho por detras, SE DEBE USAR UNA VEZ POR SESION.

# %%
# los graficos pueden guardarse como imgs, ANTES DEL SHOW.

# %%
# El lienzo se llamada FIGURE. Se puede acceder con el metodo figure

plt.figure(facecolor="orange")
plt.plot(numeros) # Mostrar los datos en el grafico
plt.show() # Mostrar el gráfico

# %%
plt.subplots(ncols=2, nrows=2) # para crear mas de 1 grafico
plt.show()

# %%
axes1 = axs[0][0]
