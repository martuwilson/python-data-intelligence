# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure();
ax = plt.axes();
plt.grid();

# %%
x=[1,2,3,5,5,6,7]
y=[1,6,3,4,5,6,7]

# %%
plt.plot(x,y);
plt.grid()
plt.show()

# %%
plt.plot(x,y, "ro-");
plt.grid()
plt.show()

# %%
plt.plot(x,y, "b*:");
plt.grid()
plt.axis([0,8,0,8])
plt.show()
