# %% [markdown]
# ## Joins de tablas con Python/Pandas

# %%
import pandas as pd

# %%
# Carga de datos
df1 = pd.read_csv('dataset_2a.csv')
df2 = pd.read_csv('dataset_2b.csv')
df3 = pd.read_csv('dataset_2c.csv')

# %%
df1.head()
# Out:
#        id                                          full_text  favorites  \
# 0  183721  Flying home to run down from the power to comi...       23.0
# 1  183722                Today we commemorate and MNML Case.      500.0
# 2  183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3  183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4  183725                                    Welcome back! 🙌      113.0
#
#    retweets  mentions           user fecha_publicado
# 0       NaN      10.0  leonardokuffo      27/01/2023
# 1      21.0       NaN  mateusmartins      27/01/2023
# 2     123.0       6.0    pedrojuarez      28/01/2023
# 3      76.0       3.0   galocastillo      28/01/2023
# 4     130.0       9.0    pedrojuarez      28/01/2023

# %%
df2.head()
# Out:
#         ciudad  followers  followees             user
# 0    GUAYAQUIL      389.0        258    leonardokuffo
# 1    SAO PAULO      982.0       1822    mateusmartins
# 2       OAXACA       12.0        129      pedrojuarez
# 3        QUITO      332.0        378     galocastillo
# 4  GUADALAJARA       21.0       2721  gabrielcarvajal

# %%
df3.head()
# Out:
#            ciudad     pais
# 0       GUAYAQUIL  ECUADOR
# 1  RIO DE JANEIRO   BRASIL
# 2     GUADALAJARA   MEXICO
# 3          OAXACA   MEXICO
# 4           QUITO  ECUADOR

# %% [markdown]
# ### Si notamos, df1 tiene en comun con df2 la columna user, asi como df2 y df3 comparten ciudad. Ahi es el praton para el join.

# %%
# Df a la izquierda y otro de derecha, el de izq es el principal. Unimos df izq que es df1 con el derecha que es df2
df_con_users = df1.merge(df2, on='user', how='left') #buscar en gpt los diferentes HOW

# %%
df_con_users.head()
# Out:
#        id                                          full_text  favorites  \
# 0  183721  Flying home to run down from the power to comi...       23.0
# 1  183722                Today we commemorate and MNML Case.      500.0
# 2  183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3  183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4  183725                                    Welcome back! 🙌      113.0
#
#    retweets  mentions           user fecha_publicado     ciudad  followers  \
# 0       NaN      10.0  leonardokuffo      27/01/2023  GUAYAQUIL      389.0
# 1      21.0       NaN  mateusmartins      27/01/2023  SAO PAULO      982.0
# 2     123.0       6.0    pedrojuarez      28/01/2023     OAXACA       12.0
# 3      76.0       3.0   galocastillo      28/01/2023      QUITO      332.0
# 4     130.0       9.0    pedrojuarez      28/01/2023     OAXACA       12.0
#
#    followees
# 0        258
# 1       1822
# 2        129
# 3        378
# 4        129

# %%
df_full = df_con_users.merge(df3, on='ciudad', how='left')

# %%
df_full.head()
# Out:
#        id                                          full_text  favorites  \
# 0  183721  Flying home to run down from the power to comi...       23.0
# 1  183722                Today we commemorate and MNML Case.      500.0
# 2  183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3  183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4  183725                                    Welcome back! 🙌      113.0
#
#    retweets  mentions           user fecha_publicado     ciudad  followers  \
# 0       NaN      10.0  leonardokuffo      27/01/2023  GUAYAQUIL      389.0
# 1      21.0       NaN  mateusmartins      27/01/2023  SAO PAULO      982.0
# 2     123.0       6.0    pedrojuarez      28/01/2023     OAXACA       12.0
# 3      76.0       3.0   galocastillo      28/01/2023      QUITO      332.0
# 4     130.0       9.0    pedrojuarez      28/01/2023     OAXACA       12.0
#
#    followees     pais
# 0        258  ECUADOR
# 1       1822   BRASIL
# 2        129   MEXICO
# 3        378  ECUADOR
# 4        129   MEXICO

# %% [markdown]
# ### Si miramos hay una column fecha. Pero tiene el dato string. Hay que pasarlo a date para que se organice bien si hacemos sorts

# %%
df_full['fecha'] = pd.to_datetime(df_full['fecha_publicado'], format='%d/%m/%Y')

# %%
df_full.head()
# Out:
#        id                                          full_text  favorites  \
# 0  183721  Flying home to run down from the power to comi...       23.0
# 1  183722                Today we commemorate and MNML Case.      500.0
# 2  183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3  183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4  183725                                    Welcome back! 🙌      113.0
#
#    retweets  mentions           user fecha_publicado     ciudad  followers  \
# 0       NaN      10.0  leonardokuffo      27/01/2023  GUAYAQUIL      389.0
# 1      21.0       NaN  mateusmartins      27/01/2023  SAO PAULO      982.0
# 2     123.0       6.0    pedrojuarez      28/01/2023     OAXACA       12.0
# 3      76.0       3.0   galocastillo      28/01/2023      QUITO      332.0
# 4     130.0       9.0    pedrojuarez      28/01/2023     OAXACA       12.0
#
#    followees     pais      fecha
# 0        258  ECUADOR 2023-01-27
# 1       1822   BRASIL 2023-01-27
# 2        129   MEXICO 2023-01-28
# 3        378  ECUADOR 2023-01-28
# 4        129   MEXICO 2023-01-28

# %%
# dia de semana de la fecha
df_full['dia_semana']= df_full['fecha'].apply(
    lambda x: x.strftime('%A-%d-%B')
)
df_full.head()
# Out:
#        id                                          full_text  favorites  \
# 0  183721  Flying home to run down from the power to comi...       23.0
# 1  183722                Today we commemorate and MNML Case.      500.0
# 2  183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3  183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4  183725                                    Welcome back! 🙌      113.0
#
#    retweets  mentions           user fecha_publicado     ciudad  followers  \
# 0       NaN      10.0  leonardokuffo      27/01/2023  GUAYAQUIL      389.0
# 1      21.0       NaN  mateusmartins      27/01/2023  SAO PAULO      982.0
# 2     123.0       6.0    pedrojuarez      28/01/2023     OAXACA       12.0
# 3      76.0       3.0   galocastillo      28/01/2023      QUITO      332.0
# 4     130.0       9.0    pedrojuarez      28/01/2023     OAXACA       12.0
#
#    followees     pais      fecha           dia_semana
# 0        258  ECUADOR 2023-01-27    Friday-27-January
# 1       1822   BRASIL 2023-01-27    Friday-27-January
# 2        129   MEXICO 2023-01-28  Saturday-28-January
# 3        378  ECUADOR 2023-01-28  Saturday-28-January
# 4        129   MEXICO 2023-01-28  Saturday-28-January

# %%
df_full['mes']= df_full['fecha'].apply(
    lambda x: x.strftime('%m/%Y')
)
df_full.head()
# Out:
#        id                                          full_text  favorites  \
# 0  183721  Flying home to run down from the power to comi...       23.0
# 1  183722                Today we commemorate and MNML Case.      500.0
# 2  183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3  183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4  183725                                    Welcome back! 🙌      113.0
#
#    retweets  mentions           user fecha_publicado     ciudad  followers  \
# 0       NaN      10.0  leonardokuffo      27/01/2023  GUAYAQUIL      389.0
# 1      21.0       NaN  mateusmartins      27/01/2023  SAO PAULO      982.0
# 2     123.0       6.0    pedrojuarez      28/01/2023     OAXACA       12.0
# 3      76.0       3.0   galocastillo      28/01/2023      QUITO      332.0
# 4     130.0       9.0    pedrojuarez      28/01/2023     OAXACA       12.0
#
#    followees     pais      fecha           dia_semana      mes
# 0        258  ECUADOR 2023-01-27    Friday-27-January  01/2023
# 1       1822   BRASIL 2023-01-27    Friday-27-January  01/2023
# 2        129   MEXICO 2023-01-28  Saturday-28-January  01/2023
# 3        378  ECUADOR 2023-01-28  Saturday-28-January  01/2023
# 4        129   MEXICO 2023-01-28  Saturday-28-January  01/2023

# %%
## fecha_publicado al ser string, puedo saltar lo que hice y hacer directo mes y año
df_full['mes_string']= df_full['fecha_publicado'].apply(
    lambda x: x[3:]
)
df_full.head()
# Out:
#        id                                          full_text  favorites  \
# 0  183721  Flying home to run down from the power to comi...       23.0
# 1  183722                Today we commemorate and MNML Case.      500.0
# 2  183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3  183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4  183725                                    Welcome back! 🙌      113.0
#
#    retweets  mentions           user fecha_publicado     ciudad  followers  \
# 0       NaN      10.0  leonardokuffo      27/01/2023  GUAYAQUIL      389.0
# 1      21.0       NaN  mateusmartins      27/01/2023  SAO PAULO      982.0
# 2     123.0       6.0    pedrojuarez      28/01/2023     OAXACA       12.0
# 3      76.0       3.0   galocastillo      28/01/2023      QUITO      332.0
# 4     130.0       9.0    pedrojuarez      28/01/2023     OAXACA       12.0
#
#    followees     pais      fecha           dia_semana      mes mes_string
# 0        258  ECUADOR 2023-01-27    Friday-27-January  01/2023    01/2023
# 1       1822   BRASIL 2023-01-27    Friday-27-January  01/2023    01/2023
# 2        129   MEXICO 2023-01-28  Saturday-28-January  01/2023    01/2023
# 3        378  ECUADOR 2023-01-28  Saturday-28-January  01/2023    01/2023
# 4        129   MEXICO 2023-01-28  Saturday-28-January  01/2023    01/2023

# %% [markdown]
# ## Agrupaciones multiples, pivotar y transporters

# %%
df_full.groupby('mes_string').agg({
    'id': 'count'
})
# Out:
#             id
# mes_string
# 01/2023     12
# 02/2023     12
# 03/2023      3

# %% [markdown]
# ## Visualizar cuantos tweets han habido por mes dentro de cada ciudad

# %%
agrupado = df_full.groupby(['mes_string', 'ciudad']).agg({
    'id': 'count'
})

agrupado
# Out:
#                            id
# mes_string ciudad
# 01/2023    GUAYAQUIL        2
#            OAXACA           4
#            QUITO            1
#            SAO PAULO        5
# 02/2023    GUADALAJARA      2
#            GUAYAQUIL        2
#            OAXACA           1
#            QUITO            3
#            RIO DE JANEIRO   4
# 03/2023    GUADALAJARA      1
#            PORTO ALEGRE     1
#            RIO DE JANEIRO   1

# %%
agrupado['ciudad'] # da error porque no es una columna, es un indice que es id
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Martin\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ciudad'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 agrupado['ciudad']
#
# File c:\Users\Martin\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\Martin\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'ciudad'

# %%
desagrupado = agrupado.reset_index(1) #ciudad pasa a ser columna ahora, y se puede ver
desagrupado
# Out:
#                     ciudad  id
# mes_string
# 01/2023          GUAYAQUIL   2
# 01/2023             OAXACA   4
# 01/2023              QUITO   1
# 01/2023          SAO PAULO   5
# 02/2023        GUADALAJARA   2
# 02/2023          GUAYAQUIL   2
# 02/2023             OAXACA   1
# 02/2023              QUITO   3
# 02/2023     RIO DE JANEIRO   4
# 03/2023        GUADALAJARA   1
# 03/2023       PORTO ALEGRE   1
# 03/2023     RIO DE JANEIRO   1

# %%
desagrupado['ciudad']
# Out:
# mes_string
# 01/2023         GUAYAQUIL
# 01/2023            OAXACA
# 01/2023             QUITO
# 01/2023         SAO PAULO
# 02/2023       GUADALAJARA
# 02/2023         GUAYAQUIL
# 02/2023            OAXACA
# 02/2023             QUITO
# 02/2023    RIO DE JANEIRO
# 03/2023       GUADALAJARA
# 03/2023      PORTO ALEGRE
# 03/2023    RIO DE JANEIRO
# Name: ciudad, dtype: object

# %% [markdown]
# ## PIVOTAR:
# ### Pivotar es una forma de transformar los datos para que puedan ser analizados de una manera más efectiva. Cada valor unico de una columna se convierte en una columna diferente.

# %%
pivotar = desagrupado.pivot(columns='ciudad')
pivotar
# Out:
#                     id                                                     \
# ciudad     GUADALAJARA GUAYAQUIL OAXACA PORTO ALEGRE QUITO RIO DE JANEIRO
# mes_string
# 01/2023            NaN       2.0    4.0          NaN   1.0            NaN
# 02/2023            2.0       2.0    1.0          NaN   3.0            4.0
# 03/2023            1.0       NaN    NaN          1.0   NaN            1.0
#
#
# ciudad     SAO PAULO
# mes_string
# 01/2023          5.0
# 02/2023          NaN
# 03/2023          NaN

# %%
pivotar[['GUAYAQUIL']] # da error porque hay dos niveles
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 pivotar[['GUAYAQUIL']]
#
# File c:\Users\Martin\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\Martin\anaconda3\Lib\site-packages\pandas\core\indexes\multi.py:2763, in MultiIndex._get_indexer_strict(self, key, axis_name)
#    2760 if len(keyarr) and not isinstance(keyarr[0], tuple):
#    2761     indexer = self._get_indexer_level_0(keyarr)
# -> 2763     self._raise_if_missing(key, indexer, axis_name)
#    2764     return self[indexer], indexer
#    2766 return super()._get_indexer_strict(key, axis_name)
#
# File c:\Users\Martin\anaconda3\Lib\site-packages\pandas\core\indexes\multi.py:2781, in MultiIndex._raise_if_missing(self, key, indexer, axis_name)
#    2779 cmask = check == -1
#    2780 if cmask.any():
# -> 2781     raise KeyError(f"{keyarr[cmask]} not in index")
#    2782 # We get here when levels still contain values which are not
#    2783 # actually in Index anymore
#    2784 raise KeyError(f"{keyarr} not in index")
#
# KeyError: "['GUAYAQUIL'] not in index"

# %%
pivotar_level = pivotar.droplevel(0, axis='columns') #con esto borramos el nivel de la columna 0 que era id si miramos en el de arriba
pivotar_level
# Out:
# ciudad      GUADALAJARA  GUAYAQUIL  OAXACA  PORTO ALEGRE  QUITO  \
# mes_string
# 01/2023             NaN        2.0     4.0           NaN    1.0
# 02/2023             2.0        2.0     1.0           NaN    3.0
# 03/2023             1.0        NaN     NaN           1.0    NaN
#
# ciudad      RIO DE JANEIRO  SAO PAULO
# mes_string
# 01/2023                NaN        5.0
# 02/2023                4.0        NaN
# 03/2023                1.0        NaN

# %%
pivotar_level[['GUAYAQUIL']]
# Out:
# ciudad      GUAYAQUIL
# mes_string
# 01/2023           2.0
# 02/2023           2.0
# 03/2023           NaN

# %%
pivotar_level.fillna(0)
